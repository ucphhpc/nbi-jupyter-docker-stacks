# %%
from pomegranate import *

# %%
i_d = DiscreteDistribution({"A": 0.25, "C": 0.25, "G": 0.25, "T": 0.25})

# %%
m1 = State(
    DiscreteDistribution({"A": 0.95, "C": 0.01, "G": 0.01, "T": 0.02}), name="M1"
)
m2 = State(
    DiscreteDistribution({"A": 0.003, "C": 0.99, "G": 0.003, "T": 0.004}), name="M2"
)
m3 = State(
    DiscreteDistribution({"A": 0.01, "C": 0.01, "G": 0.01, "T": 0.97}), name="M3"
)

# %%
i0 = State(i_d, name="I0")
i1 = State(i_d, name="I1")
i2 = State(i_d, name="I2")
i3 = State(i_d, name="I3")
