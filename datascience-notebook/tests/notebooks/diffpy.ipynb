# %%
from diffpy.Structure.tests import test
test().wasSuccessful()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7b8e7af1e22b> in <module>()
# ----> 1 from diffpy.Structure.tests import test
#       2 test().wasSuccessful()
#
# ModuleNotFoundError: No module named 'diffpy'

# %%
from diffpy.srfit.tests import test
test().wasSuccessful()
