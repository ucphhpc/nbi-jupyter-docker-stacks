# %%
from math import pi, pow
from math import factorial as f
# General python stuff
assert 2 == 3-1

result = 0
for i in range(10):
    result += 1
assert result == 10

a = pi * (12.34/2)**2
assert a == 119.59697657024448

x = 3
y = 3 - (pow(x, 3)/f(3)) + (pow(x, 5)/f(5)) - (pow(x, 7)/f(7)) + (pow(x, 9)/f(9)) - (pow(x, 11)/f(11)) + (pow(x, 13)/f(13))
assert y == 0.14113062718531458
